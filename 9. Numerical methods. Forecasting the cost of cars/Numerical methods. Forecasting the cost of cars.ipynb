# %% [markdown]
# Сервис по продаже автомобилей с пробегом «Не бит, не крашен» разрабатывает приложение для привлечения новых клиентов. В нём можно быстро узнать рыночную стоимость своего автомобиля. В вашем распоряжении исторические данные: технические характеристики, комплектации и цены автомобилей. Вам нужно построить модель для определения стоимости.
#
# Заказчику важны:
#
# - качество предсказания;
# - скорость предсказания;
# - время обучения.

# %% [markdown]
# # План работы:
#
# 1) [Изучение и обработка данных.](#id_1)
#
# 2) [Обучение моделей, подборка гиперпараметров.](#id_2)
#
# 3) [Анализ работы моделей.](#id_3)
#
# 4) [Общий вывод.](#id_4)
#
# 5) [Бонус.](#id_5)

# %% [markdown]
# <a id='id_1'></a>
# # 1. Подготовка данных

# %%
# Импортируем все необходимые библиотеки
# В процессе работы список будет пополняться
import pandas as pd
import numpy as np
import time
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 1.1 Чтение данных

# %%
data = pd.read_csv('/datasets/autos.csv')
data.info()
data.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
# DateCrawled          354369 non-null object
# Price                354369 non-null int64
# VehicleType          316879 non-null object
# RegistrationYear     354369 non-null int64
# Gearbox              334536 non-null object
# Power                354369 non-null int64
# Model                334664 non-null object
# Kilometer            354369 non-null int64
# RegistrationMonth    354369 non-null int64
# FuelType             321474 non-null object
# Brand                354369 non-null object
# NotRepaired          283215 non-null object
# DateCreated          354369 non-null object
# NumberOfPictures     354369 non-null int64
# PostalCode           354369 non-null int64
# LastSeen             354369 non-null object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB
#            DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  2016-03-24 11:52:17    480         NaN              1993  manual      0
# 1  2016-03-24 10:58:45  18300       coupe              2011  manual    190
# 2  2016-03-14 12:52:21   9800         suv              2004    auto    163
# 3  2016-03-17 16:54:04   1500       small              2001  manual     75
# 4  2016-03-31 17:25:20   3600       small              2008  manual     69
#
#    Model  Kilometer  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf     150000                  0    petrol  volkswagen         NaN
# 1    NaN     125000                  5  gasoline        audi         yes
# 2  grand     125000                  8  gasoline        jeep         NaN
# 3   golf     150000                  6    petrol  volkswagen          no
# 4  fabia      90000                  7  gasoline       skoda          no
#
#            DateCreated  NumberOfPictures  PostalCode             LastSeen
# 0  2016-03-24 00:00:00                 0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00                 0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00                 0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00                 0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00                 0       60437  2016-04-06 10:17:21

# %%
data.isnull().sum()
# Out:
# DateCrawled              0
# Price                    0
# VehicleType          37490
# RegistrationYear         0
# Gearbox              19833
# Power                    0
# Model                19705
# Kilometer                0
# RegistrationMonth        0
# FuelType             32895
# Brand                    0
# NotRepaired          71154
# DateCreated              0
# NumberOfPictures         0
# PostalCode               0
# LastSeen                 0
# dtype: int64

# %% [markdown]
# Данные загружены, время анализировать.
# У нас имеются 16 колонок и 354369 строк. В столбцах VehicleType, Gearbox, Model, FuelType и NotRepaired - есть пропущенные значения.

# %%
data.describe()
# Out:
#                Price  RegistrationYear          Power      Kilometer  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %% [markdown]
# В колонках Цена и Мощность - присутствуют нулевые значения, их следует обработать. Значения в столбце Количество фотографий - везде ноль, его можно смело удалять, на анализ он никак не влияет. Аналогично, для анализа нам не пригодятся так же столбцы PostalCode и RegistrationMonth (на цену они не влияют, в то время как качество модели может страдать). Так же есть аномальные значения в столбце RegistrationYear.

# %% [markdown]
# ## 1.2 Обработка пропусков и аномалий

# %%
del data['PostalCode'], data['NumberOfPictures'], data['RegistrationMonth']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 13 columns):
# DateCrawled         354369 non-null object
# Price               354369 non-null int64
# VehicleType         316879 non-null object
# RegistrationYear    354369 non-null int64
# Gearbox             334536 non-null object
# Power               354369 non-null int64
# Model               334664 non-null object
# Kilometer           354369 non-null int64
# FuelType            321474 non-null object
# Brand               354369 non-null object
# NotRepaired         283215 non-null object
# DateCreated         354369 non-null object
# LastSeen            354369 non-null object
# dtypes: int64(4), object(9)
# memory usage: 35.1+ MB

# %%
# Обработаем столбец Price
data.Price.plot(kind='hist', bins =100)

# %%
# Значения с ценой = 0 явный выброс, удаляем все нулевые значения
data = data.query('Price > 0')
data.Price.sort_values().head(10)
# Out:
# 25095     1
# 353252    1
# 66163     1
# 134280    1
# 66253     1
# 89957     1
# 192113    1
# 66308     1
# 184965    1
# 1340      1
# Name: Price, dtype: int64

# %%
# Теперь минимальная цена = 1? Попробуем минимальную цену от 200 Евро
data = data.query('Price > 200')
data.Price.sort_values().head(10)
# Out:
# 290665    202
# 28094     205
# 36284     205
# 175108    209
# 183153    209
# 101354    210
# 4345      210
# 89295     210
# 183570    210
# 143413    210
# Name: Price, dtype: int64

# %%
# Обработаем столбец Power
# Чтобы избавиться от аномальных значений, возьмем диапозон мощности от 60 до 250 л.с.
data = data.query('Power > 60 & Power < 250')
data.describe()
# Out:
#                Price  RegistrationYear          Power      Kilometer
# count  258056.000000     258056.000000  258056.000000  258056.000000
# mean     5160.274119       2003.955599     124.844018  128561.920668
# std      4537.471408         28.786962      41.313916   36734.986192
# min       202.000000       1000.000000      61.000000    5000.000000
# 25%      1650.000000       2000.000000      90.000000  125000.000000
# 50%      3600.000000       2004.000000     116.000000  150000.000000
# 75%      7400.000000       2008.000000     150.000000  150000.000000
# max     20000.000000       9999.000000     249.000000  150000.000000

# %%
# Обработаем столбец RegistrationYear
data['RegistrationYear'].sort_values(ascending=True).head(30)
# Out:
# 256532    1000
# 18224     1500
# 203230    1910
# 23750     1910
# 62803     1910
# 295868    1937
# 338109    1937
# 88033     1942
# 230679    1942
# 305821    1943
# 326241    1947
# 271162    1948
# 27525     1949
# 103192    1950
# 74705     1950
# 174755    1950
# 85423     1951
# 111389    1951
# 163050    1951
# 133222    1952
# 254249    1952
# 34572     1953
# 317802    1953
# 284693    1954
# 186403    1955
# 109349    1955
# 171996    1955
# 316508    1955
# 274861    1956
# 258928    1956
# Name: RegistrationYear, dtype: int64

# %%
data['RegistrationYear'].sort_values(ascending=False).head(30)
# Out:
# 128677    9999
# 320452    8200
# 158283    6000
# 53678     5911
# 326556    5911
# 229905    5000
# 124840    5000
# 309880    5000
# 322234    5000
# 146507    5000
# 278390    4500
# 46741     2900
# 255866    2800
# 101989    2019
# 35506     2019
# 148759    2019
# 62996     2019
# 57074     2019
# 74469     2019
# 62809     2019
# 178620    2019
# 182995    2018
# 65332     2018
# 65460     2018
# 311098    2018
# 97133     2018
# 24364     2018
# 274414    2018
# 97701     2018
# 275618    2018
# Name: RegistrationYear, dtype: int64

# %%
# Есть много выбросов (такие как год регистрации автомобиля больше 2019 или меньше 1942), удалим их
data = data.query('RegistrationYear > 1980 & RegistrationYear < 2020')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 256666 entries, 1 to 354368
# Data columns (total 13 columns):
# DateCrawled         256666 non-null object
# Price               256666 non-null int64
# VehicleType         240141 non-null object
# RegistrationYear    256666 non-null int64
# Gearbox             252419 non-null object
# Power               256666 non-null int64
# Model               247454 non-null object
# Kilometer           256666 non-null int64
# FuelType            241679 non-null object
# Brand               256666 non-null object
# NotRepaired         220099 non-null object
# DateCreated         256666 non-null object
# LastSeen            256666 non-null object
# dtypes: int64(4), object(9)
# memory usage: 27.4+ MB

# %%
# Обработаем столбец VehicleType
data['VehicleType'].value_counts()
# Out:
# sedan          76438
# wagon          56993
# small          39736
# bus            25599
# convertible    17253
# coupe          12327
# suv             9780
# other           2015
# Name: VehicleType, dtype: int64

# %%
data['VehicleType'].isnull().sum()
# Out:
# 16525

# %%
# Всего у нас пропущено 18212 значений. Самостоятельно заполнить у нас возможности нет, т.к. нельзя выделить какое-либо 
# лидирующее значение, так что пропуски мы удалим
data.dropna(subset=['VehicleType'], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240141 entries, 1 to 354368
# Data columns (total 13 columns):
# DateCrawled         240141 non-null object
# Price               240141 non-null int64
# VehicleType         240141 non-null object
# RegistrationYear    240141 non-null int64
# Gearbox             237200 non-null object
# Power               240141 non-null int64
# Model               233083 non-null object
# Kilometer           240141 non-null int64
# FuelType            231891 non-null object
# Brand               240141 non-null object
# NotRepaired         210800 non-null object
# DateCreated         240141 non-null object
# LastSeen            240141 non-null object
# dtypes: int64(4), object(9)
# memory usage: 25.6+ MB

# %%
# Обработаем столбец Gearbox
data['Gearbox'].value_counts()
# Out:
# manual    187828
# auto       49372
# Name: Gearbox, dtype: int64

# %%
# Большинство значений - manual, а значит пропуски заполним этим значением
data['Gearbox'] = data['Gearbox'].fillna('manual')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240141 entries, 1 to 354368
# Data columns (total 13 columns):
# DateCrawled         240141 non-null object
# Price               240141 non-null int64
# VehicleType         240141 non-null object
# RegistrationYear    240141 non-null int64
# Gearbox             240141 non-null object
# Power               240141 non-null int64
# Model               233083 non-null object
# Kilometer           240141 non-null int64
# FuelType            231891 non-null object
# Brand               240141 non-null object
# NotRepaired         210800 non-null object
# DateCreated         240141 non-null object
# LastSeen            240141 non-null object
# dtypes: int64(4), object(9)
# memory usage: 25.6+ MB

# %%
# Пропуски в столбце Model самостоятельно восстановить не получится (заполнять пропуски модальным значением может быть ошибкой)
# Просто удаляем нули
data.dropna(subset=['Model'], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233083 entries, 2 to 354368
# Data columns (total 13 columns):
# DateCrawled         233083 non-null object
# Price               233083 non-null int64
# VehicleType         233083 non-null object
# RegistrationYear    233083 non-null int64
# Gearbox             233083 non-null object
# Power               233083 non-null int64
# Model               233083 non-null object
# Kilometer           233083 non-null int64
# FuelType            226188 non-null object
# Brand               233083 non-null object
# NotRepaired         205948 non-null object
# DateCreated         233083 non-null object
# LastSeen            233083 non-null object
# dtypes: int64(4), object(9)
# memory usage: 24.9+ MB

# %%
# Столбцы FuelType и NotRepaired - пропуски заменим на самые частые значения
data['FuelType'].value_counts()
# Out:
# petrol      139816
# gasoline     81988
# lpg           3734
# cng            417
# hybrid         174
# other           35
# electric        24
# Name: FuelType, dtype: int64

# %%
data['FuelType']=data['FuelType'].fillna('petrol')
data['NotRepaired'].value_counts()
# Out:
# no     185264
# yes     20684
# Name: NotRepaired, dtype: int64

# %%
data['NotRepaired']=data['NotRepaired'].fillna('no')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233083 entries, 2 to 354368
# Data columns (total 13 columns):
# DateCrawled         233083 non-null object
# Price               233083 non-null int64
# VehicleType         233083 non-null object
# RegistrationYear    233083 non-null int64
# Gearbox             233083 non-null object
# Power               233083 non-null int64
# Model               233083 non-null object
# Kilometer           233083 non-null int64
# FuelType            233083 non-null object
# Brand               233083 non-null object
# NotRepaired         233083 non-null object
# DateCreated         233083 non-null object
# LastSeen            233083 non-null object
# dtypes: int64(4), object(9)
# memory usage: 24.9+ MB

# %% [markdown]
# Итак, пропуски все обработаны. Датафрейм теперь состоит из 233083 строк, вместо 354369 изначальных. Потери в количестве немалые, зато мы приобрели в качестве.
#
# Для корректной работы модели - нам не пригодятся столбцы DataCrawled, DateCreated, LastSeen (на цену они не влияют).

# %%
del data['DateCrawled'], data['DateCreated'], data['LastSeen']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233083 entries, 2 to 354368
# Data columns (total 10 columns):
# Price               233083 non-null int64
# VehicleType         233083 non-null object
# RegistrationYear    233083 non-null int64
# Gearbox             233083 non-null object
# Power               233083 non-null int64
# Model               233083 non-null object
# Kilometer           233083 non-null int64
# FuelType            233083 non-null object
# Brand               233083 non-null object
# NotRepaired         233083 non-null object
# dtypes: int64(4), object(6)
# memory usage: 19.6+ MB

# %% [markdown]
# ## 1.3 Преобразование данных

# %%
# Отделим целевой признак от признаков
data_target = data['Price']
data_features = data.drop('Price', axis=1)
# data_features2 понадобится нам позже
data_features2 = data.drop('Price', axis=1)
data_features.head(5)
# Out:
#    VehicleType  RegistrationYear Gearbox  Power    Model  Kilometer  FuelType  \
# 2          suv              2004    auto    163    grand     125000  gasoline
# 3        small              2001  manual     75     golf     150000    petrol
# 4        small              2008  manual     69    fabia      90000  gasoline
# 5        sedan              1995  manual    102      3er     150000    petrol
# 6  convertible              2004  manual    109  2_reihe     150000    petrol
#
#         Brand NotRepaired
# 2        jeep          no
# 3  volkswagen          no
# 4       skoda          no
# 5         bmw         yes
# 6     peugeot          no

# %%
# Теперь следует преобразовать данные
data_features = pd.get_dummies(data_features, drop_first=True)
data_features.describe()
# Out:
#        RegistrationYear          Power      Kilometer  \
# count     233083.000000  233083.000000  233083.000000
# mean        2003.363411     125.573607  128211.903056
# std            5.552585      41.414567   36735.280458
# min         1981.000000      61.000000    5000.000000
# 25%         2000.000000      95.000000  125000.000000
# 50%         2004.000000     116.000000  150000.000000
# 75%         2007.000000     150.000000  150000.000000
# max         2018.000000     249.000000  150000.000000
#
#        VehicleType_convertible  VehicleType_coupe  VehicleType_other  \
# count            233083.000000       233083.00000      233083.000000
# mean                  0.071794            0.05060           0.007976
# std                   0.258147            0.21918           0.088950
# min                   0.000000            0.00000           0.000000
# 25%                   0.000000            0.00000           0.000000
# 50%                   0.000000            0.00000           0.000000
# 75%                   0.000000            0.00000           0.000000
# max                   1.000000            1.00000           1.000000
#
#        VehicleType_sedan  VehicleType_small  VehicleType_suv  \
# count      233083.000000      233083.000000    233083.000000
# mean            0.319131           0.165430         0.040102
# std             0.466141           0.371569         0.196198
# min             0.000000           0.000000         0.000000
# 25%             0.000000           0.000000         0.000000
# 50%             0.000000           0.000000         0.000000
# 75%             1.000000           0.000000         0.000000
# max             1.000000           1.000000         1.000000
#
#        VehicleType_wagon  ...     Brand_seat    Brand_skoda    Brand_smart  \
# count      233083.000000  ...  233083.000000  233083.000000  233083.000000
# mean            0.238023  ...       0.017603       0.018414       0.010782
# std             0.425874  ...       0.131504       0.134443       0.103273
# min             0.000000  ...       0.000000       0.000000       0.000000
# 25%             0.000000  ...       0.000000       0.000000       0.000000
# 50%             0.000000  ...       0.000000       0.000000       0.000000
# 75%             0.000000  ...       0.000000       0.000000       0.000000
# max             1.000000  ...       1.000000       1.000000       1.000000
#
#         Brand_subaru   Brand_suzuki   Brand_toyota  Brand_trabant  \
# count  233083.000000  233083.000000  233083.000000  233083.000000
# mean        0.002244       0.006869       0.016196       0.000004
# std         0.047316       0.082593       0.126229       0.002071
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        Brand_volkswagen    Brand_volvo  NotRepaired_yes
# count     233083.000000  233083.000000    233083.000000
# mean           0.208943       0.011022         0.088741
# std            0.406554       0.104405         0.284370
# min            0.000000       0.000000         0.000000
# 25%            0.000000       0.000000         0.000000
# 50%            0.000000       0.000000         0.000000
# 75%            0.000000       0.000000         0.000000
# max            1.000000       1.000000         1.000000
#
# [8 rows x 300 columns]

# %%
# Нормализуем данные
scaler = StandardScaler()
scaler.fit(data_features)
data_norm_feat = scaler.transform(data_features)
data_norm_feat = pd.DataFrame(data_norm_feat, columns=data_features.columns)
data_norm_feat.describe()
# Out:
#        RegistrationYear         Power     Kilometer  VehicleType_convertible  \
# count      2.330830e+05  2.330830e+05  2.330830e+05             2.330830e+05
# mean      -1.266803e-14 -1.726644e-16  1.076104e-16            -1.746764e-17
# std        1.000002e+00  1.000002e+00  1.000002e+00             1.000002e+00
# min       -4.027576e+00 -1.559204e+00 -3.354055e+00            -2.781137e-01
# 25%       -6.057392e-01 -7.382348e-01 -8.743393e-02            -2.781137e-01
# 50%        1.146475e-01 -2.311657e-01  5.931122e-01            -2.781137e-01
# 75%        6.549375e-01  5.898032e-01  5.931122e-01            -2.781137e-01
# max        2.636001e+00  2.980272e+00  5.931122e-01             3.595651e+00
#
#        VehicleType_coupe  VehicleType_other  VehicleType_sedan  \
# count       2.330830e+05       2.330830e+05       2.330830e+05
# mean        8.901485e-18      -5.182371e-18      -4.089501e-17
# std         1.000002e+00       1.000002e+00       1.000002e+00
# min        -2.308610e-01      -8.966506e-02      -6.846249e-01
# 25%        -2.308610e-01      -8.966506e-02      -6.846249e-01
# 50%        -2.308610e-01      -8.966506e-02      -6.846249e-01
# 75%        -2.308610e-01      -8.966506e-02       1.460654e+00
# max         4.331610e+00       1.115262e+01       1.460654e+00
#
#        VehicleType_small  VehicleType_suv  VehicleType_wagon  ...  \
# count       2.330830e+05     2.330830e+05       2.330830e+05  ...
# mean        6.923038e-17     6.333163e-17       1.027024e-16  ...
# std         1.000002e+00     1.000002e+00       1.000002e+00  ...
# min        -4.452217e-01    -2.043940e-01      -5.589049e-01  ...
# 25%        -4.452217e-01    -2.043940e-01      -5.589049e-01  ...
# 50%        -4.452217e-01    -2.043940e-01      -5.589049e-01  ...
# 75%        -4.452217e-01    -2.043940e-01      -5.589049e-01  ...
# max         2.246072e+00     4.892511e+00       1.789213e+00  ...
#
#          Brand_seat   Brand_skoda   Brand_smart  Brand_subaru  Brand_suzuki  \
# count  2.330830e+05  2.330830e+05  2.330830e+05  2.330830e+05  2.330830e+05
# mean   6.322493e-17  1.652262e-17  2.726842e-17 -9.648356e-18  1.864129e-17
# std    1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00  1.000002e+00
# min   -1.338604e-01 -1.369652e-01 -1.043986e-01 -4.742238e-02 -8.316432e-02
# 25%   -1.338604e-01 -1.369652e-01 -1.043986e-01 -4.742238e-02 -8.316432e-02
# 50%   -1.338604e-01 -1.369652e-01 -1.043986e-01 -4.742238e-02 -8.316432e-02
# 75%   -1.338604e-01 -1.369652e-01 -1.043986e-01 -4.742238e-02 -8.316432e-02
# max    7.470472e+00  7.301122e+00  9.578669e+00  2.108709e+01  1.202439e+01
#
#        Brand_toyota  Brand_trabant  Brand_volkswagen   Brand_volvo  \
# count  2.330830e+05   2.330830e+05      2.330830e+05  2.330830e+05
# mean   5.343939e-17  -1.234624e-18      9.104207e-17 -2.627767e-17
# std    1.000002e+00   1.000002e+00      1.000002e+00  1.000002e+00
# min   -1.283066e-01  -2.071313e-03     -5.139368e-01 -1.055683e-01
# 25%   -1.283066e-01  -2.071313e-03     -5.139368e-01 -1.055683e-01
# 50%   -1.283066e-01  -2.071313e-03     -5.139368e-01 -1.055683e-01
# 75%   -1.283066e-01  -2.071313e-03     -5.139368e-01 -1.055683e-01
# max    7.793834e+00   4.827857e+02      1.945765e+00  9.472543e+00
#
#        NotRepaired_yes
# count     2.330830e+05
# mean      5.456732e-18
# std       1.000002e+00
# min      -3.120621e-01
# 25%      -3.120621e-01
# 50%      -3.120621e-01
# 75%      -3.120621e-01
# max       3.204490e+00
#
# [8 rows x 300 columns]

# %%
# Создадим обучающую, валидационную и тестовую выборки в соотношение 60%, 20% и 20% соотвественно
x_train, x_another, y_train, y_another = train_test_split(data_norm_feat, data_target, random_state = 12345, test_size=0.4)
x_valid, x_test, y_valid, y_test = train_test_split(x_another, y_another, random_state=12345, test_size=0.5)
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139849 entries, 34339 to 217570
# Columns: 300 entries, RegistrationYear to NotRepaired_yes
# dtypes: float64(300)
# memory usage: 321.2 MB

# %%
x_valid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46617 entries, 226739 to 57561
# Columns: 300 entries, RegistrationYear to NotRepaired_yes
# dtypes: float64(300)
# memory usage: 107.1 MB

# %%
x_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46617 entries, 132557 to 232739
# Columns: 300 entries, RegistrationYear to NotRepaired_yes
# dtypes: float64(300)
# memory usage: 107.1 MB

# %% [markdown]
# <a id='id_2'></a>
# # 2. Обучение моделей

# %% [markdown]
# ### 2.1 LightGBM

# %%
# Подбираем параметры
for est in range (1, 52, 10):
    start=time.time()
    model=LGBMRegressor(n_estimators=est)
    model.fit(x_train, y_train)
    predict=model.predict(x_valid)
    accuracy=mean_squared_error(y_valid, predict)**0.5
    print(est, '-', accuracy, ', time', time.time()-start)
# Out:
# 1 - 4244.234098352123 , time 10.720906019210815
# 11 - 2471.9096152062652 , time 15.905495643615723
# 21 - 1974.1403546799029 , time 55.499343395233154
# 31 - 1800.5334948739562 , time 115.13377690315247
# 41 - 1721.4429678344823 , time 38.65143036842346
# 51 - 1676.2552361522903 , time 40.31349992752075

# %%
# Значение 51 показывает самое меньшее значение RMSE, оставляем его
for depth in range (1, 5):
    start=time.time()
    model=LGBMRegressor(n_estimators=51, max_depth=depth)
    model.fit(x_train, y_train)
    predict=model.predict(x_valid)
    accuracy=mean_squared_error(y_valid, predict)**0.5
    print(depth, '-', accuracy, ', time', time.time()-start)
# Out:
# 1 - 2552.08067804437 , time 19.885313749313354
# 2 - 2128.47570619306 , time 42.410908699035645
# 3 - 1943.4116783286865 , time 61.47873640060425
# 4 - 1819.5529383140845 , time 104.23098564147949

# %% [markdown]
# Остановимся на значении 4, т.к. последующие значения сильно увеличивают время работы при несильном уменьшении ошибки.
#
# Параметры вышли следующие: n_estimators=51, max_depth=4.

# %%
lgbm = LGBMRegressor(n_estimators=51, max_depth=4)

# %% [markdown]
# ### 2.2 Catboost

# %%
# Подбираем параметры
start=time.time()
model=CatBoostRegressor(iterations=133)
model.fit(x_train, y_train)
predict=model.predict(x_valid)
accuracy=mean_squared_error(y_valid, predict)**0.5
# Out:
# 0:	learn: 4485.1100103	total: 19.6ms	remaining: 2.59s
# 1:	learn: 4394.4534728	total: 121ms	remaining: 7.92s
# 2:	learn: 4307.5791870	total: 223ms	remaining: 9.67s
# 3:	learn: 4222.1300258	total: 412ms	remaining: 13.3s
# 4:	learn: 4138.8425564	total: 517ms	remaining: 13.2s
# 5:	learn: 4058.6551578	total: 620ms	remaining: 13.1s
# 6:	learn: 3983.2740126	total: 723ms	remaining: 13s
# 7:	learn: 3909.8472916	total: 910ms	remaining: 14.2s
# 8:	learn: 3838.9247950	total: 1.01s	remaining: 13.9s
# 9:	learn: 3770.7379956	total: 1.11s	remaining: 13.7s
# 10:	learn: 3704.9741150	total: 1.22s	remaining: 13.5s
# 11:	learn: 3642.2738207	total: 1.32s	remaining: 13.3s
# 12:	learn: 3581.7405804	total: 1.51s	remaining: 13.9s
# 13:	learn: 3521.8448886	total: 1.61s	remaining: 13.7s
# 14:	learn: 3465.4789522	total: 1.71s	remaining: 13.5s
# 15:	learn: 3411.0804420	total: 1.9s	remaining: 13.9s
# 16:	learn: 3359.7478063	total: 2.01s	remaining: 13.7s
# 17:	learn: 3309.6667156	total: 2.11s	remaining: 13.5s
# 18:	learn: 3260.0457030	total: 2.3s	remaining: 13.8s
# 19:	learn: 3211.3583438	total: 2.4s	remaining: 13.6s
# 20:	learn: 3164.7617782	total: 2.51s	remaining: 13.4s
# 21:	learn: 3121.3516298	total: 2.7s	remaining: 13.6s
# 22:	learn: 3079.7392579	total: 2.8s	remaining: 13.4s
# 23:	learn: 3038.9219496	total: 2.91s	remaining: 13.2s
# 24:	learn: 2999.9931089	total: 3.01s	remaining: 13s
# 25:	learn: 2962.1616991	total: 3.2s	remaining: 13.2s
# 26:	learn: 2925.8948722	total: 3.3s	remaining: 12.9s
# 27:	learn: 2891.1581436	total: 3.4s	remaining: 12.8s
# 28:	learn: 2858.1602294	total: 3.5s	remaining: 12.6s
# 29:	learn: 2826.1672974	total: 3.61s	remaining: 12.4s
# 30:	learn: 2795.5144994	total: 3.79s	remaining: 12.5s
# 31:	learn: 2766.0712418	total: 3.89s	remaining: 12.3s
# 32:	learn: 2736.9978190	total: 4s	remaining: 12.1s
# 33:	learn: 2709.2922952	total: 4.1s	remaining: 11.9s
# 34:	learn: 2682.1588119	total: 4.29s	remaining: 12s
# 35:	learn: 2656.1136219	total: 4.39s	remaining: 11.8s
# 36:	learn: 2630.8144338	total: 4.5s	remaining: 11.7s
# 37:	learn: 2607.3714111	total: 4.6s	remaining: 11.5s
# 38:	learn: 2583.2869064	total: 4.79s	remaining: 11.5s
# 39:	learn: 2561.3818985	total: 4.89s	remaining: 11.4s
# 40:	learn: 2539.7576927	total: 4.99s	remaining: 11.2s
# 41:	learn: 2519.3927657	total: 5.09s	remaining: 11s
# 42:	learn: 2499.3022352	total: 5.28s	remaining: 11.1s
# 43:	learn: 2480.7380971	total: 5.38s	remaining: 10.9s
# 44:	learn: 2462.1912208	total: 5.49s	remaining: 10.7s
# 45:	learn: 2444.6700572	total: 5.59s	remaining: 10.6s
# 46:	learn: 2427.3225980	total: 5.69s	remaining: 10.4s
# 47:	learn: 2410.4703474	total: 5.88s	remaining: 10.4s
# 48:	learn: 2394.8500727	total: 5.98s	remaining: 10.3s
# 49:	learn: 2379.8626790	total: 6.08s	remaining: 10.1s
# 50:	learn: 2365.1987453	total: 6.19s	remaining: 9.95s
# 51:	learn: 2350.5037594	total: 6.37s	remaining: 9.93s
# 52:	learn: 2336.7143918	total: 6.48s	remaining: 9.78s
# 53:	learn: 2323.6577016	total: 6.58s	remaining: 9.62s
# 54:	learn: 2311.3987032	total: 6.68s	remaining: 9.47s
# 55:	learn: 2298.5465431	total: 6.87s	remaining: 9.45s
# 56:	learn: 2283.5009095	total: 6.97s	remaining: 9.29s
# 57:	learn: 2271.2551039	total: 7.07s	remaining: 9.15s
# 58:	learn: 2259.9424479	total: 7.18s	remaining: 9s
# 59:	learn: 2249.0882776	total: 7.28s	remaining: 8.86s
# 60:	learn: 2235.9773671	total: 7.47s	remaining: 8.81s
# 61:	learn: 2225.6526938	total: 7.57s	remaining: 8.67s
# 62:	learn: 2214.0348465	total: 7.67s	remaining: 8.53s
# 63:	learn: 2204.4543726	total: 7.77s	remaining: 8.38s
# 64:	learn: 2195.3292719	total: 8.01s	remaining: 8.38s
# 65:	learn: 2185.9857296	total: 8.08s	remaining: 8.2s
# 66:	learn: 2175.4530238	total: 8.18s	remaining: 8.05s
# 67:	learn: 2166.9217398	total: 8.36s	remaining: 7.99s
# 68:	learn: 2158.7081138	total: 8.46s	remaining: 7.85s
# 69:	learn: 2150.6701479	total: 8.56s	remaining: 7.71s
# 70:	learn: 2142.6624104	total: 8.66s	remaining: 7.57s
# 71:	learn: 2133.1937496	total: 8.77s	remaining: 7.43s
# 72:	learn: 2126.2571213	total: 8.96s	remaining: 7.36s
# 73:	learn: 2119.0287216	total: 9.06s	remaining: 7.22s
# 74:	learn: 2111.7182001	total: 9.16s	remaining: 7.08s
# 75:	learn: 2104.3962084	total: 9.26s	remaining: 6.95s
# 76:	learn: 2097.9402540	total: 9.36s	remaining: 6.81s
# 77:	learn: 2091.7393631	total: 9.46s	remaining: 6.67s
# 78:	learn: 2083.8093093	total: 9.65s	remaining: 6.6s
# 79:	learn: 2077.7324818	total: 9.75s	remaining: 6.46s
# 80:	learn: 2071.2463345	total: 9.85s	remaining: 6.32s
# 81:	learn: 2065.7667162	total: 9.96s	remaining: 6.19s
# 82:	learn: 2060.4653046	total: 10.1s	remaining: 6.06s
# 83:	learn: 2055.2226275	total: 10.2s	remaining: 5.92s
# 84:	learn: 2049.7498240	total: 10.3s	remaining: 5.84s
# 85:	learn: 2044.1991776	total: 10.4s	remaining: 5.71s
# 86:	learn: 2039.3318155	total: 10.6s	remaining: 5.58s
# 87:	learn: 2034.4773540	total: 10.7s	remaining: 5.45s
# 88:	learn: 2029.4611241	total: 10.8s	remaining: 5.36s
# 89:	learn: 2024.3706441	total: 10.9s	remaining: 5.23s
# 90:	learn: 2019.1049877	total: 11s	remaining: 5.1s
# 91:	learn: 2014.0754112	total: 11.1s	remaining: 4.97s
# 92:	learn: 2008.6629413	total: 11.3s	remaining: 4.84s
# 93:	learn: 2004.5237218	total: 11.3s	remaining: 4.71s
# 94:	learn: 2000.5412750	total: 11.4s	remaining: 4.58s
# 95:	learn: 1996.5286284	total: 11.6s	remaining: 4.48s
# 96:	learn: 1992.4001114	total: 11.7s	remaining: 4.36s
# 97:	learn: 1988.9536900	total: 11.8s	remaining: 4.23s
# 98:	learn: 1985.2543702	total: 11.9s	remaining: 4.1s
# 99:	learn: 1980.7720731	total: 12.1s	remaining: 3.98s
# 100:	learn: 1976.6334194	total: 12.2s	remaining: 3.88s
# 101:	learn: 1971.3350331	total: 12.3s	remaining: 3.75s
# 102:	learn: 1967.2038758	total: 12.4s	remaining: 3.62s
# 103:	learn: 1963.4078800	total: 12.5s	remaining: 3.5s
# 104:	learn: 1959.6613777	total: 12.7s	remaining: 3.4s
# 105:	learn: 1955.6955046	total: 12.8s	remaining: 3.27s
# 106:	learn: 1952.3944880	total: 12.9s	remaining: 3.14s
# 107:	learn: 1949.3251227	total: 13s	remaining: 3.02s
# 108:	learn: 1946.3283755	total: 13.2s	remaining: 2.91s
# 109:	learn: 1943.2082079	total: 13.3s	remaining: 2.79s
# 110:	learn: 1939.0478791	total: 13.4s	remaining: 2.66s
# 111:	learn: 1936.3728166	total: 13.5s	remaining: 2.54s
# 112:	learn: 1933.2318974	total: 13.7s	remaining: 2.43s
# 113:	learn: 1930.6241325	total: 13.8s	remaining: 2.3s
# 114:	learn: 1927.4430014	total: 13.9s	remaining: 2.18s
# 115:	learn: 1924.4927919	total: 14s	remaining: 2.05s
# 116:	learn: 1921.8332446	total: 14.1s	remaining: 1.93s
# 117:	learn: 1919.1382918	total: 14.2s	remaining: 1.81s
# 118:	learn: 1915.4097633	total: 14.4s	remaining: 1.7s
# 119:	learn: 1912.7137283	total: 14.5s	remaining: 1.57s
# 120:	learn: 1910.4311061	total: 14.6s	remaining: 1.45s
# 121:	learn: 1907.6774163	total: 14.7s	remaining: 1.33s
# 122:	learn: 1905.1551531	total: 14.8s	remaining: 1.2s
# 123:	learn: 1902.5456166	total: 15s	remaining: 1.09s
# 124:	learn: 1900.4934908	total: 15.1s	remaining: 967ms
# 125:	learn: 1898.1224748	total: 15.2s	remaining: 845ms
# 126:	learn: 1896.3170397	total: 15.3s	remaining: 724ms
# 127:	learn: 1894.4902642	total: 15.4s	remaining: 603ms
# 128:	learn: 1892.2338324	total: 15.6s	remaining: 484ms
# 129:	learn: 1890.3588405	total: 15.7s	remaining: 363ms
# 130:	learn: 1888.6253173	total: 15.8s	remaining: 241ms
# 131:	learn: 1886.4921721	total: 15.9s	remaining: 121ms
# 132:	learn: 1884.7798503	total: 16.1s	remaining: 0us

# %%
start=time.time()
model=CatBoostRegressor(iterations=133, depth=11)
model.fit(x_train, y_train)
predict=model.predict(x_valid)
accuracy=mean_squared_error(y_valid, predict)**0.5
# Out:
# 0:	learn: 4475.6870402	total: 174ms	remaining: 22.9s
# 1:	learn: 4376.3180310	total: 443ms	remaining: 29s
# 2:	learn: 4278.8524824	total: 653ms	remaining: 28.3s
# 3:	learn: 4186.4859574	total: 858ms	remaining: 27.7s
# 4:	learn: 4097.5601470	total: 1.14s	remaining: 29.3s
# 5:	learn: 4012.1732613	total: 1.35s	remaining: 28.6s
# 6:	learn: 3928.8747336	total: 1.57s	remaining: 28.3s
# 7:	learn: 3847.5089507	total: 1.84s	remaining: 28.8s
# 8:	learn: 3768.9883871	total: 2.07s	remaining: 28.5s
# 9:	learn: 3694.0209385	total: 2.34s	remaining: 28.8s
# 10:	learn: 3621.4688104	total: 2.55s	remaining: 28.3s
# 11:	learn: 3550.8818860	total: 2.84s	remaining: 28.6s
# 12:	learn: 3483.1971621	total: 3.04s	remaining: 28.1s
# 13:	learn: 3418.8205055	total: 3.34s	remaining: 28.4s
# 14:	learn: 3356.8959566	total: 3.54s	remaining: 27.9s
# 15:	learn: 3296.9643110	total: 3.75s	remaining: 27.4s
# 16:	learn: 3238.9539154	total: 4.03s	remaining: 27.5s
# 17:	learn: 3183.0834181	total: 4.26s	remaining: 27.2s
# 18:	learn: 3129.4726626	total: 4.53s	remaining: 27.2s
# 19:	learn: 3078.0112277	total: 4.83s	remaining: 27.3s
# 20:	learn: 3026.3571517	total: 5.04s	remaining: 26.9s
# 21:	learn: 2977.8850430	total: 5.33s	remaining: 26.9s
# 22:	learn: 2931.8206743	total: 5.54s	remaining: 26.5s
# 23:	learn: 2886.9668970	total: 5.75s	remaining: 26.1s
# 24:	learn: 2844.0327269	total: 6.03s	remaining: 26s
# 25:	learn: 2802.7627136	total: 6.23s	remaining: 25.6s
# 26:	learn: 2762.6275373	total: 6.44s	remaining: 25.3s
# 27:	learn: 2724.6106323	total: 6.72s	remaining: 25.2s
# 28:	learn: 2687.4431832	total: 6.93s	remaining: 24.9s
# 29:	learn: 2651.6558213	total: 7.14s	remaining: 24.5s
# 30:	learn: 2617.5298739	total: 7.42s	remaining: 24.4s
# 31:	learn: 2582.0202636	total: 7.62s	remaining: 24.1s
# 32:	learn: 2550.5406636	total: 7.83s	remaining: 23.7s
# 33:	learn: 2518.2526876	total: 8.11s	remaining: 23.6s
# 34:	learn: 2486.4809694	total: 8.32s	remaining: 23.3s
# 35:	learn: 2458.1583323	total: 8.53s	remaining: 23s
# 36:	learn: 2430.8124271	total: 8.82s	remaining: 22.9s
# 37:	learn: 2405.1075442	total: 9.11s	remaining: 22.8s
# 38:	learn: 2379.7073585	total: 9.32s	remaining: 22.5s
# 39:	learn: 2355.3020559	total: 9.53s	remaining: 22.2s
# 40:	learn: 2332.0729260	total: 9.81s	remaining: 22s
# 41:	learn: 2309.0522667	total: 10s	remaining: 21.7s
# 42:	learn: 2287.2639824	total: 10.2s	remaining: 21.4s
# 43:	learn: 2266.2985132	total: 10.5s	remaining: 21.3s
# 44:	learn: 2245.6835023	total: 10.7s	remaining: 21s
# 45:	learn: 2226.2821777	total: 11s	remaining: 20.8s
# 46:	learn: 2207.5708114	total: 11.2s	remaining: 20.5s
# 47:	learn: 2188.6601040	total: 11.4s	remaining: 20.2s
# 48:	learn: 2171.2759065	total: 11.7s	remaining: 20.1s
# 49:	learn: 2155.1650925	total: 11.9s	remaining: 19.8s
# 50:	learn: 2138.6569748	total: 12.1s	remaining: 19.5s
# 51:	learn: 2122.6399494	total: 12.4s	remaining: 19.3s
# 52:	learn: 2106.2901086	total: 12.6s	remaining: 19s
# 53:	learn: 2092.1239487	total: 12.9s	remaining: 18.9s
# 54:	learn: 2078.8986796	total: 13.1s	remaining: 18.6s
# 55:	learn: 2065.6608817	total: 13.4s	remaining: 18.4s
# 56:	learn: 2053.2592685	total: 13.6s	remaining: 18.1s
# 57:	learn: 2042.0586363	total: 13.8s	remaining: 17.9s
# 58:	learn: 2028.6851509	total: 14.1s	remaining: 17.7s
# 59:	learn: 2017.2629654	total: 14.3s	remaining: 17.4s
# 60:	learn: 2007.1749187	total: 14.5s	remaining: 17.1s
# 61:	learn: 1996.3742396	total: 14.8s	remaining: 16.9s
# 62:	learn: 1986.6987846	total: 15s	remaining: 16.7s
# 63:	learn: 1976.9374449	total: 15.2s	remaining: 16.4s
# 64:	learn: 1967.6330005	total: 15.5s	remaining: 16.2s
# 65:	learn: 1958.9707162	total: 15.7s	remaining: 15.9s
# 66:	learn: 1949.2558644	total: 15.9s	remaining: 15.7s
# 67:	learn: 1941.4156097	total: 16.2s	remaining: 15.5s
# 68:	learn: 1933.3626593	total: 16.4s	remaining: 15.2s
# 69:	learn: 1924.4796851	total: 16.7s	remaining: 15s
# 70:	learn: 1916.6975484	total: 16.9s	remaining: 14.7s
# 71:	learn: 1908.5353044	total: 17.1s	remaining: 14.5s
# 72:	learn: 1900.9484105	total: 17.4s	remaining: 14.3s
# 73:	learn: 1892.8984897	total: 17.6s	remaining: 14s
# 74:	learn: 1886.5818180	total: 17.8s	remaining: 13.8s
# 75:	learn: 1879.0931007	total: 18.1s	remaining: 13.6s
# 76:	learn: 1872.7136917	total: 18.3s	remaining: 13.3s
# 77:	learn: 1866.6729949	total: 18.6s	remaining: 13.1s
# 78:	learn: 1860.1112283	total: 18.8s	remaining: 12.8s
# 79:	learn: 1854.5375826	total: 19s	remaining: 12.6s
# 80:	learn: 1848.1388970	total: 19.3s	remaining: 12.4s
# 81:	learn: 1842.8073859	total: 19.5s	remaining: 12.1s
# 82:	learn: 1837.8011981	total: 19.7s	remaining: 11.9s
# 83:	learn: 1832.3156594	total: 20s	remaining: 11.7s
# 84:	learn: 1827.6376680	total: 20.2s	remaining: 11.4s
# 85:	learn: 1823.1925928	total: 20.5s	remaining: 11.2s
# 86:	learn: 1818.7298042	total: 20.7s	remaining: 10.9s
# 87:	learn: 1814.4860189	total: 20.9s	remaining: 10.7s
# 88:	learn: 1810.2854716	total: 21.2s	remaining: 10.5s
# 89:	learn: 1806.1881956	total: 21.4s	remaining: 10.2s
# 90:	learn: 1802.0630614	total: 21.6s	remaining: 9.96s
# 91:	learn: 1798.2736601	total: 21.8s	remaining: 9.71s
# 92:	learn: 1794.3749240	total: 22.1s	remaining: 9.49s
# 93:	learn: 1791.2145948	total: 22.3s	remaining: 9.24s
# 94:	learn: 1787.7860160	total: 22.5s	remaining: 8.99s
# 95:	learn: 1784.0492009	total: 22.8s	remaining: 8.77s
# 96:	learn: 1781.0870887	total: 23s	remaining: 8.52s
# 97:	learn: 1777.1403105	total: 23.2s	remaining: 8.27s
# 98:	learn: 1774.0085313	total: 23.5s	remaining: 8.05s
# 99:	learn: 1771.3095935	total: 23.7s	remaining: 7.81s
# 100:	learn: 1768.5362172	total: 23.9s	remaining: 7.56s
# 101:	learn: 1765.6739968	total: 24.1s	remaining: 7.34s
# 102:	learn: 1763.0403883	total: 24.4s	remaining: 7.09s
# 103:	learn: 1760.0935044	total: 24.6s	remaining: 6.85s
# 104:	learn: 1757.4191813	total: 24.8s	remaining: 6.63s
# 105:	learn: 1754.7006658	total: 25.1s	remaining: 6.38s
# 106:	learn: 1752.3646317	total: 25.3s	remaining: 6.16s
# 107:	learn: 1749.2659681	total: 25.6s	remaining: 5.91s
# 108:	learn: 1747.0526656	total: 25.8s	remaining: 5.67s
# 109:	learn: 1744.6926039	total: 26s	remaining: 5.43s
# 110:	learn: 1742.0201670	total: 26.2s	remaining: 5.2s
# 111:	learn: 1739.9914105	total: 26.5s	remaining: 4.96s
# 112:	learn: 1737.5295907	total: 26.7s	remaining: 4.72s
# 113:	learn: 1735.0638972	total: 26.9s	remaining: 4.49s
# 114:	learn: 1732.8863828	total: 27.1s	remaining: 4.25s
# 115:	learn: 1730.2844501	total: 27.4s	remaining: 4.02s
# 116:	learn: 1728.4179702	total: 27.6s	remaining: 3.78s
# 117:	learn: 1726.7570916	total: 27.9s	remaining: 3.54s
# 118:	learn: 1724.6644980	total: 28.1s	remaining: 3.31s
# 119:	learn: 1722.9243677	total: 28.3s	remaining: 3.07s
# 120:	learn: 1721.2157011	total: 28.6s	remaining: 2.84s
# 121:	learn: 1719.6090050	total: 28.8s	remaining: 2.6s
# 122:	learn: 1718.0158956	total: 29s	remaining: 2.36s
# 123:	learn: 1716.4427043	total: 29.3s	remaining: 2.13s
# 124:	learn: 1714.6485512	total: 29.5s	remaining: 1.89s
# 125:	learn: 1713.2503670	total: 29.8s	remaining: 1.66s
# 126:	learn: 1711.8963559	total: 30s	remaining: 1.42s
# 127:	learn: 1710.3381119	total: 30.2s	remaining: 1.18s
# 128:	learn: 1708.7831985	total: 30.5s	remaining: 947ms
# 129:	learn: 1707.2513140	total: 30.7s	remaining: 709ms
# 130:	learn: 1705.5408390	total: 30.9s	remaining: 472ms
# 131:	learn: 1703.9149799	total: 31.2s	remaining: 237ms
# 132:	learn: 1702.2768557	total: 31.4s	remaining: 0us

# %%
# Лучший результат - 11
cb=CatBoostRegressor(iterations=133, depth=11)

# %% [markdown]
# Из подбора гиперпараметров можно сделать следующий вывод - чем больше значения у гиперпараметров - тем медленнее работает модель, но сильнее улучшается её качество. Остановимся, пока, на указанных выше параметрах.

# %% [markdown]
# ### 2.3 DecissionTreeRegressor

# %%
for depth in range(1, 11):
    start=time.time()
    model = DecisionTreeRegressor(max_depth=depth, random_state=123)
    model.fit(x_train, y_train)
    predict = model.predict(x_valid)
    accuracy=mean_squared_error(y_valid, predict)**0.5
    print(depth, '-', accuracy, ', time', time.time()-start)
# Out:
# 1 - 3464.6663199839168 , time 0.4322850704193115
# 2 - 3056.2761975192 , time 0.7429513931274414
# 3 - 2648.205769692134 , time 1.1814794540405273
# 4 - 2443.013437253702 , time 1.4017333984375
# 5 - 2305.7261520288816 , time 1.9774346351623535
# 6 - 2198.332200400508 , time 2.049873113632202
# 7 - 2107.6846440884033 , time 2.5690743923187256
# 8 - 2031.2557481450838 , time 2.5411767959594727
# 9 - 1975.0615487544746 , time 2.785043478012085
# 10 - 1910.166467417463 , time 3.0094387531280518

# %%
# Оставялем значение 10
for split in range(2, 11):
    start=time.time()
    model = DecisionTreeRegressor(max_depth=10, random_state=123, min_samples_split=split)
    model.fit(x_train, y_train)
    predict = model.predict(x_valid)
    accuracy=mean_squared_error(y_valid, predict)**0.5
    print(split, '-', accuracy, ', time', time.time()-start)
# Out:
# 2 - 1910.166467417463 , time 2.973012924194336
# 3 - 1909.8074511274917 , time 3.0454769134521484
# 4 - 1905.9486683025254 , time 2.8953685760498047
# 5 - 1909.8016854665007 , time 3.1767163276672363
# 6 - 1907.7008143615099 , time 4.132702827453613
# 7 - 1909.5484992201293 , time 4.369153261184692
# 8 - 1909.006083516185 , time 2.91290545463562
# 9 - 1912.6853889835727 , time 2.9681591987609863
# 10 - 1911.4970160277314 , time 2.9392597675323486

# %%
# Лучшее значение - 4, хотя сильно оно показатели не меняет
dtr = DecisionTreeRegressor(max_depth=10, random_state=123, min_samples_split=4)

# %% [markdown]
# ### 2.4 RandomForest

# %%
# ЭТА КОМАНДА ПОМОГАЕТ УБИРАТЬ ПРЕДУПРЕЖДЕНИЯ
import warnings
warnings.filterwarnings('ignore')

# %%
for depth in range(1, 11):
    start=time.time()
    model = RandomForestRegressor(max_depth=depth, random_state=123)
    model.fit(x_train, y_train)
    predict = model.predict(x_valid)
    accuracy=mean_squared_error(y_valid, predict)**0.5
    print(depth, '-', accuracy, ', time', time.time()-start)
# Out:
# 1 - 3363.106332445761 , time 2.138859748840332
# 2 - 2951.264525083452 , time 4.314027309417725
# 3 - 2603.9356228898346 , time 6.7440338134765625
# 4 - 2389.240178170767 , time 9.293168306350708
# 5 - 2242.9009179876452 , time 10.916149139404297
# 6 - 2129.9535235228427 , time 13.219451189041138
# 7 - 2038.39039986463 , time 15.001970052719116
# 8 - 1951.5199560556102 , time 17.1714448928833
# 9 - 1881.8211315013436 , time 17.58962321281433
# 10 - 1819.545112026633 , time 18.965007543563843

# %%
# Лучшее значение - 10
for est in range (1, 11):
    start=time.time()
    model = RandomForestRegressor(max_depth=10, n_estimators=est, random_state=123)
    model.fit(x_train, y_train)
    predict = model.predict(x_valid)
    accuracy=mean_squared_error(y_valid, predict)**0.5
    print(est, '-', accuracy, ', time', time.time()-start)
# Out:
# 1 - 1953.972526038666 , time 2.0808427333831787
# 2 - 1891.059853766587 , time 4.153751373291016
# 3 - 1862.7795458992875 , time 5.742893695831299
# 4 - 1849.078198876395 , time 7.540847063064575
# 5 - 1840.440788015788 , time 9.521743535995483
# 6 - 1833.102064412224 , time 11.390902996063232
# 7 - 1824.2340646136804 , time 13.496291637420654
# 8 - 1821.3136575968895 , time 15.003194808959961
# 9 - 1820.5408600644994 , time 16.77011728286743
# 10 - 1819.545112026633 , time 18.6054265499115

# %%
# Создаем модель
rf = RandomForestRegressor(max_depth=10, n_estimators=10, random_state=123)

# %% [markdown]
# ## Вывод по п.2:
# Теперь у нас есть 4 готовых модели с подобранными параметрами, в следующем пункте мы проверим их на тестовой выборке.

# %% [markdown]
# <a id='id_3'></a>
# # 3. Анализ моделей

# %%
# LGBMRegressor
start=time.time()
lgbm.fit(x_train, y_train)
training_time = time.time()-start
second = time.time()
predict=lgbm.predict(x_test)
prediction_time = time.time()-second
accuracy=mean_squared_error(y_test, predict)**0.5
print("RMSE составляет" , accuracy, ', training_time', training_time, ', prediction_time', prediction_time)
# Out:
# RMSE составляет 1811.4306311844996 , training_time 27.16418147087097 , prediction_time 0.683499813079834

# %%
# CatBoost
start=time.time()
cb.fit(x_train, y_train)
training_time = time.time()-start
second = time.time()
predict=cb.predict(x_test)
prediction_time = time.time()-second
accuracy=mean_squared_error(y_test, predict)**0.5
print("RMSE составляет" , accuracy, ', training_time', training_time, ', prediction_time', prediction_time)
# Out:
# 0:	learn: 4475.6870402	total: 191ms	remaining: 25.2s
# 1:	learn: 4376.3180310	total: 398ms	remaining: 26.1s
# 2:	learn: 4278.8524824	total: 604ms	remaining: 26.2s
# 3:	learn: 4186.4859574	total: 807ms	remaining: 26s
# 4:	learn: 4097.5601470	total: 1.09s	remaining: 27.9s
# 5:	learn: 4012.1732613	total: 1.29s	remaining: 27.4s
# 6:	learn: 3928.8747336	total: 1.5s	remaining: 27.1s
# 7:	learn: 3847.5089507	total: 1.79s	remaining: 28s
# 8:	learn: 3768.9883871	total: 2s	remaining: 27.6s
# 9:	learn: 3694.0209385	total: 2.29s	remaining: 28.1s
# 10:	learn: 3621.4688104	total: 2.49s	remaining: 27.6s
# 11:	learn: 3550.8818860	total: 2.7s	remaining: 27.2s
# 12:	learn: 3483.1971621	total: 2.98s	remaining: 27.5s
# 13:	learn: 3418.8205055	total: 3.19s	remaining: 27.1s
# 14:	learn: 3356.8959566	total: 3.4s	remaining: 26.7s
# 15:	learn: 3296.9643110	total: 3.68s	remaining: 26.9s
# 16:	learn: 3238.9539154	total: 3.88s	remaining: 26.5s
# 17:	learn: 3183.0834181	total: 4.09s	remaining: 26.1s
# 18:	learn: 3129.4726626	total: 4.38s	remaining: 26.3s
# 19:	learn: 3078.0112277	total: 4.58s	remaining: 25.9s
# 20:	learn: 3026.3571517	total: 4.78s	remaining: 25.5s
# 21:	learn: 2977.8850430	total: 5.07s	remaining: 25.6s
# 22:	learn: 2931.8206743	total: 5.28s	remaining: 25.2s
# 23:	learn: 2886.9668970	total: 5.49s	remaining: 24.9s
# 24:	learn: 2844.0327269	total: 5.78s	remaining: 25s
# 25:	learn: 2802.7627136	total: 5.98s	remaining: 24.6s
# 26:	learn: 2762.6275373	total: 6.27s	remaining: 24.6s
# 27:	learn: 2724.6106323	total: 6.48s	remaining: 24.3s
# 28:	learn: 2687.4431832	total: 6.68s	remaining: 24s
# 29:	learn: 2651.6558213	total: 6.97s	remaining: 23.9s
# 30:	learn: 2617.5298739	total: 7.27s	remaining: 23.9s
# 31:	learn: 2582.0202636	total: 7.47s	remaining: 23.6s
# 32:	learn: 2550.5406636	total: 7.76s	remaining: 23.5s
# 33:	learn: 2518.2526876	total: 7.97s	remaining: 23.2s
# 34:	learn: 2486.4809694	total: 8.27s	remaining: 23.2s
# 35:	learn: 2458.1583323	total: 8.47s	remaining: 22.8s
# 36:	learn: 2430.8124271	total: 8.76s	remaining: 22.7s
# 37:	learn: 2405.1075442	total: 8.96s	remaining: 22.4s
# 38:	learn: 2379.7073585	total: 9.17s	remaining: 22.1s
# 39:	learn: 2355.3020559	total: 9.46s	remaining: 22s
# 40:	learn: 2332.0729260	total: 9.67s	remaining: 21.7s
# 41:	learn: 2309.0522667	total: 9.87s	remaining: 21.4s
# 42:	learn: 2287.2639824	total: 10.2s	remaining: 21.3s
# 43:	learn: 2266.2985132	total: 10.4s	remaining: 21s
# 44:	learn: 2245.6835023	total: 10.6s	remaining: 20.7s
# 45:	learn: 2226.2821777	total: 10.9s	remaining: 20.5s
# 46:	learn: 2207.5708114	total: 11.1s	remaining: 20.2s
# 47:	learn: 2188.6601040	total: 11.3s	remaining: 20.1s
# 48:	learn: 2171.2759065	total: 11.6s	remaining: 19.8s
# 49:	learn: 2155.1650925	total: 11.8s	remaining: 19.5s
# 50:	learn: 2138.6569748	total: 12s	remaining: 19.4s
# 51:	learn: 2122.6399494	total: 12.3s	remaining: 19.1s
# 52:	learn: 2106.2901086	total: 12.5s	remaining: 18.8s
# 53:	learn: 2092.1239487	total: 12.7s	remaining: 18.6s
# 54:	learn: 2078.8986796	total: 12.9s	remaining: 18.4s
# 55:	learn: 2065.6608817	total: 13.2s	remaining: 18.1s
# 56:	learn: 2053.2592685	total: 13.4s	remaining: 17.8s
# 57:	learn: 2042.0586363	total: 13.6s	remaining: 17.6s
# 58:	learn: 2028.6851509	total: 13.9s	remaining: 17.4s
# 59:	learn: 2017.2629654	total: 14.1s	remaining: 17.2s
# 60:	learn: 2007.1749187	total: 14.3s	remaining: 16.9s
# 61:	learn: 1996.3742396	total: 14.6s	remaining: 16.8s
# 62:	learn: 1986.6987846	total: 14.8s	remaining: 16.5s
# 63:	learn: 1976.9374449	total: 15.1s	remaining: 16.2s
# 64:	learn: 1967.6330005	total: 15.3s	remaining: 16s
# 65:	learn: 1958.9707162	total: 15.5s	remaining: 15.8s
# 66:	learn: 1949.2558644	total: 15.7s	remaining: 15.5s
# 67:	learn: 1941.4156097	total: 16s	remaining: 15.3s
# 68:	learn: 1933.3626593	total: 16.2s	remaining: 15.1s
# 69:	learn: 1924.4796851	total: 16.5s	remaining: 14.9s
# 70:	learn: 1916.6975484	total: 16.7s	remaining: 14.6s
# 71:	learn: 1908.5353044	total: 16.9s	remaining: 14.4s
# 72:	learn: 1900.9484105	total: 17.2s	remaining: 14.2s
# 73:	learn: 1892.8984897	total: 17.4s	remaining: 13.9s
# 74:	learn: 1886.5818180	total: 17.6s	remaining: 13.6s
# 75:	learn: 1879.0931007	total: 17.9s	remaining: 13.4s
# 76:	learn: 1872.7136917	total: 18.1s	remaining: 13.2s
# 77:	learn: 1866.6729949	total: 18.3s	remaining: 12.9s
# 78:	learn: 1860.1112283	total: 18.6s	remaining: 12.7s
# 79:	learn: 1854.5375826	total: 18.8s	remaining: 12.5s
# 80:	learn: 1848.1388970	total: 19s	remaining: 12.2s
# 81:	learn: 1842.8073859	total: 19.3s	remaining: 12s
# 82:	learn: 1837.8011981	total: 19.5s	remaining: 11.8s
# 83:	learn: 1832.3156594	total: 19.8s	remaining: 11.6s
# 84:	learn: 1827.6376680	total: 20s	remaining: 11.3s
# 85:	learn: 1823.1925928	total: 20.2s	remaining: 11.1s
# 86:	learn: 1818.7298042	total: 20.5s	remaining: 10.8s
# 87:	learn: 1814.4860189	total: 20.7s	remaining: 10.6s
# 88:	learn: 1810.2854716	total: 20.9s	remaining: 10.3s
# 89:	learn: 1806.1881956	total: 21.2s	remaining: 10.1s
# 90:	learn: 1802.0630614	total: 21.4s	remaining: 9.88s
# 91:	learn: 1798.2736601	total: 21.6s	remaining: 9.63s
# 92:	learn: 1794.3749240	total: 21.8s	remaining: 9.39s
# 93:	learn: 1791.2145948	total: 22.1s	remaining: 9.17s
# 94:	learn: 1787.7860160	total: 22.3s	remaining: 8.93s
# 95:	learn: 1784.0492009	total: 22.6s	remaining: 8.71s
# 96:	learn: 1781.0870887	total: 22.8s	remaining: 8.47s
# 97:	learn: 1777.1403105	total: 23s	remaining: 8.22s
# 98:	learn: 1774.0085313	total: 23.3s	remaining: 8s
# 99:	learn: 1771.3095935	total: 23.5s	remaining: 7.76s
# 100:	learn: 1768.5362172	total: 23.8s	remaining: 7.54s
# 101:	learn: 1765.6739968	total: 24s	remaining: 7.3s
# 102:	learn: 1763.0403883	total: 24.3s	remaining: 7.08s
# 103:	learn: 1760.0935044	total: 24.5s	remaining: 6.83s
# 104:	learn: 1757.4191813	total: 24.7s	remaining: 6.59s
# 105:	learn: 1754.7006658	total: 24.9s	remaining: 6.34s
# 106:	learn: 1752.3646317	total: 25.2s	remaining: 6.12s
# 107:	learn: 1749.2659681	total: 25.4s	remaining: 5.88s
# 108:	learn: 1747.0526656	total: 25.7s	remaining: 5.66s
# 109:	learn: 1744.6926039	total: 25.9s	remaining: 5.42s
# 110:	learn: 1742.0201670	total: 26.1s	remaining: 5.18s
# 111:	learn: 1739.9914105	total: 26.4s	remaining: 4.95s
# 112:	learn: 1737.5295907	total: 26.7s	remaining: 4.72s
# 113:	learn: 1735.0638972	total: 26.9s	remaining: 4.48s
# 114:	learn: 1732.8863828	total: 27.1s	remaining: 4.24s
# 115:	learn: 1730.2844501	total: 27.4s	remaining: 4.01s
# 116:	learn: 1728.4179702	total: 27.6s	remaining: 3.77s
# 117:	learn: 1726.7570916	total: 27.9s	remaining: 3.54s
# 118:	learn: 1724.6644980	total: 28.1s	remaining: 3.3s
# 119:	learn: 1722.9243677	total: 28.3s	remaining: 3.06s
# 120:	learn: 1721.2157011	total: 28.5s	remaining: 2.83s
# 121:	learn: 1719.6090050	total: 28.8s	remaining: 2.6s
# 122:	learn: 1718.0158956	total: 29s	remaining: 2.36s
# 123:	learn: 1716.4427043	total: 29.2s	remaining: 2.12s
# 124:	learn: 1714.6485512	total: 29.5s	remaining: 1.89s
# 125:	learn: 1713.2503670	total: 29.7s	remaining: 1.65s
# 126:	learn: 1711.8963559	total: 29.9s	remaining: 1.41s
# 127:	learn: 1710.3381119	total: 30.1s	remaining: 1.18s
# 128:	learn: 1708.7831985	total: 30.4s	remaining: 942ms
# 129:	learn: 1707.2513140	total: 30.6s	remaining: 706ms
# 130:	learn: 1705.5408390	total: 30.8s	remaining: 470ms
# 131:	learn: 1703.9149799	total: 31.1s	remaining: 235ms
# 132:	learn: 1702.2768557	total: 31.3s	remaining: 0us
# RMSE составляет 1707.9829892653536 , training_time 36.24906802177429 , prediction_time 0.03738999366760254

# %%
# DecissionTree
start=time.time()
dtr.fit(x_train, y_train)
training_time = time.time()-start
second = time.time()
predict=dtr.predict(x_test)
prediction_time = time.time()-second
accuracy=mean_squared_error(y_test, predict)**0.5
print("RMSE составляет" , accuracy, ', training_time', training_time, ', prediction_time', prediction_time)
# Out:
# RMSE составляет 1914.4331176500975 , training_time 2.890923261642456 , prediction_time 0.05453610420227051

# %%
# RandomForest
start=time.time()
rf.fit(x_train, y_train)
training_time = time.time()-start
second = time.time()
predict=rf.predict(x_test)
prediction_time = time.time()-second
accuracy=mean_squared_error(y_test, predict)**0.5
print("RMSE составляет" , accuracy, ', training_time', training_time, ', prediction_time', prediction_time)
# Out:
# RMSE составляет 1814.5210143949553 , training_time 18.429893016815186 , prediction_time 0.10291624069213867

# %%
regressor = {'RMSE':[1811, 1707, 1914, 1814, ], 'training_time':[105, 38, 3, 18], 'prediction_time':[0.73, 0.04, 0.04, 0.0]}
index = ['LGBMRegressor', 'CatBoost', 'DecissionTree', 'RandomForest']
all_regr = pd.DataFrame(regressor, index=index)
all_regr
# Out:
#                RMSE  training_time  prediction_time
# LGBMRegressor  1811            105             0.73
# CatBoost       1707             38             0.04
# DecissionTree  1914              3             0.04
# RandomForest   1814             18             0.00

# %% [markdown]
# <a id='id_4'></a>
# # 4. Общий вывод

# %% [markdown]
# При сравнении LGBM и RandomForest - качество предсказаний примерно одинаковое, но большая разница по скорости обучения и предсказания. Модели же CatBoost и DecissionTree имеют самую высокую скорость предсказаний, но при этом Древо Решений обучается намного быстрее всех, но качество страдает, а CatBoost имеет самое высокое качество, при относительно чуть хужем значении времени обучения.
#
# Т.к. заказчика интересуют одновременно все три параметра - для использования я бы рекомендовал модель CatBoost, т.к. обучение не такое уж и долгое, но при этом самая высокая скорость предсказаний (для пользователей приложения это будет иметь очень важное значение) и лучшее качество (что, очевидно, самая важная деталь из всех).

# %% [markdown]
# <a id='id_5'></a>
# # 5. Бонус

# %% [markdown]
# Перед обучением моделей категориальные признаки были преобразованы при помощи функции get_dummies. Из теории известно, что для модели Catboost нет необходимости в данном шаге, поэтому, ради эксперимента, проверим насколько изменится качество регрессии.

# %%
x_train, x_another, y_train, y_another = train_test_split(data_features2, data_target, random_state = 12345, test_size=0.4)
x_valid, x_test, y_valid, y_test = train_test_split(x_another, y_another, random_state=12345, test_size=0.5)
x_train.head(5)
# Out:
#         VehicleType  RegistrationYear Gearbox  Power     Model  Kilometer  \
# 52364         sedan              1999  manual    116    vectra     150000
# 291444        small              1999  manual     70      golf     150000
# 159677        wagon              2009    auto    204  c_klasse     125000
# 41214         small              2008  manual     68        c3     150000
# 18618   convertible              2007  manual    140       eos     150000
#
#         FuelType          Brand NotRepaired
# 52364     petrol           opel          no
# 291444    petrol     volkswagen         yes
# 159677  gasoline  mercedes_benz          no
# 41214   gasoline        citroen          no
# 18618   gasoline     volkswagen          no

# %%
start=time.time()
cb=CatBoostRegressor(iterations=133, depth=11, cat_features=['VehicleType', 'Gearbox', 'Model', 'FuelType', 'Brand', 'NotRepaired'])
cb.fit(x_train, y_train)
training_time = time.time()-start
second = time.time()
predict=cb.predict(x_test)
prediction_time = time.time()-second
accuracy=mean_squared_error(y_test, predict)**0.5
print("RMSE составляет" , accuracy, ', training_time', training_time, ', prediction_time', prediction_time)
# Out:
# 0:	learn: 4479.9405198	total: 216ms	remaining: 28.5s
# 1:	learn: 4383.0813007	total: 620ms	remaining: 40.6s
# 2:	learn: 4288.3598852	total: 1.01s	remaining: 43.9s
# 3:	learn: 4197.4441348	total: 1.4s	remaining: 45.3s
# 4:	learn: 4109.2933308	total: 1.8s	remaining: 46.1s
# 5:	learn: 4023.1049111	total: 2.12s	remaining: 44.9s
# 6:	learn: 3941.5927053	total: 2.51s	remaining: 45.2s
# 7:	learn: 3862.3016359	total: 2.82s	remaining: 44.1s
# 8:	learn: 3784.6619384	total: 3.21s	remaining: 44.2s
# 9:	learn: 3711.2302853	total: 3.61s	remaining: 44.4s
# 10:	learn: 3640.4611296	total: 4.01s	remaining: 44.5s
# 11:	learn: 3571.9992102	total: 4.4s	remaining: 44.3s
# 12:	learn: 3505.4940659	total: 4.71s	remaining: 43.5s
# 13:	learn: 3441.4534849	total: 5.11s	remaining: 43.4s
# 14:	learn: 3379.8944230	total: 5.49s	remaining: 43.2s
# 15:	learn: 3321.4031526	total: 5.81s	remaining: 42.5s
# 16:	learn: 3264.0382297	total: 6.2s	remaining: 42.3s
# 17:	learn: 3209.8788201	total: 6.6s	remaining: 42.2s
# 18:	learn: 3156.5558380	total: 6.99s	remaining: 41.9s
# 19:	learn: 3106.1251132	total: 7.3s	remaining: 41.3s
# 20:	learn: 3057.3448378	total: 7.69s	remaining: 41s
# 21:	learn: 3009.6707299	total: 8.08s	remaining: 40.8s
# 22:	learn: 2964.6916516	total: 8.4s	remaining: 40.2s
# 23:	learn: 2921.3921883	total: 8.79s	remaining: 39.9s
# 24:	learn: 2879.0479699	total: 9.19s	remaining: 39.7s
# 25:	learn: 2838.1560360	total: 9.58s	remaining: 39.4s
# 26:	learn: 2799.0216980	total: 9.9s	remaining: 38.9s
# 27:	learn: 2762.1555301	total: 10.3s	remaining: 38.6s
# 28:	learn: 2726.1859003	total: 10.7s	remaining: 38.3s
# 29:	learn: 2693.2717337	total: 11s	remaining: 37.7s
# 30:	learn: 2660.1028967	total: 11.4s	remaining: 37.5s
# 31:	learn: 2629.0954938	total: 11.7s	remaining: 36.9s
# 32:	learn: 2598.9142834	total: 12.1s	remaining: 36.6s
# 33:	learn: 2563.9282148	total: 12.5s	remaining: 36.3s
# 34:	learn: 2531.3234650	total: 12.8s	remaining: 35.8s
# 35:	learn: 2499.1457545	total: 13.2s	remaining: 35.5s
# 36:	learn: 2469.3093182	total: 13.6s	remaining: 35.2s
# 37:	learn: 2440.2536122	total: 13.9s	remaining: 34.7s
# 38:	learn: 2412.7469726	total: 14.3s	remaining: 34.4s
# 39:	learn: 2386.3739697	total: 14.7s	remaining: 34.1s
# 40:	learn: 2361.4488980	total: 15s	remaining: 33.6s
# 41:	learn: 2336.6360892	total: 15.4s	remaining: 33.3s
# 42:	learn: 2313.6650322	total: 15.8s	remaining: 33s
# 43:	learn: 2290.9449211	total: 16.2s	remaining: 32.7s
# 44:	learn: 2270.5803758	total: 16.5s	remaining: 32.2s
# 45:	learn: 2250.0609894	total: 16.9s	remaining: 31.9s
# 46:	learn: 2230.6502710	total: 17.3s	remaining: 31.6s
# 47:	learn: 2211.2274628	total: 17.6s	remaining: 31.1s
# 48:	learn: 2193.2069550	total: 18s	remaining: 30.8s
# 49:	learn: 2175.9947939	total: 18.4s	remaining: 30.5s
# 50:	learn: 2159.5003855	total: 18.7s	remaining: 30s
# 51:	learn: 2140.8838774	total: 19.1s	remaining: 29.7s
# 52:	learn: 2122.4509511	total: 19.4s	remaining: 29.2s
# 53:	learn: 2104.5391245	total: 19.8s	remaining: 28.9s
# 54:	learn: 2087.4048757	total: 20.2s	remaining: 28.6s
# 55:	learn: 2071.5955747	total: 20.6s	remaining: 28.3s
# 56:	learn: 2055.9825700	total: 20.9s	remaining: 27.8s
# 57:	learn: 2040.9715726	total: 21.3s	remaining: 27.5s
# 58:	learn: 2027.2145475	total: 21.6s	remaining: 27.2s
# 59:	learn: 2013.5290076	total: 22s	remaining: 26.7s
# 60:	learn: 2000.5657997	total: 22.4s	remaining: 26.4s
# 61:	learn: 1988.4555379	total: 22.8s	remaining: 26.1s
# 62:	learn: 1976.5719759	total: 23.2s	remaining: 25.7s
# 63:	learn: 1965.3902834	total: 23.5s	remaining: 25.4s
# 64:	learn: 1954.4125852	total: 23.9s	remaining: 25s
# 65:	learn: 1943.9616891	total: 24.2s	remaining: 24.6s
# 66:	learn: 1934.1508287	total: 24.6s	remaining: 24.2s
# 67:	learn: 1924.7329979	total: 25s	remaining: 23.9s
# 68:	learn: 1915.7106848	total: 25.3s	remaining: 23.5s
# 69:	learn: 1906.7434692	total: 25.7s	remaining: 23.1s
# 70:	learn: 1897.9649061	total: 26s	remaining: 22.7s
# 71:	learn: 1889.9269862	total: 26.4s	remaining: 22.4s
# 72:	learn: 1882.6346455	total: 26.8s	remaining: 22s
# 73:	learn: 1875.1214984	total: 27.1s	remaining: 21.6s
# 74:	learn: 1867.7468777	total: 27.5s	remaining: 21.2s
# 75:	learn: 1861.1717520	total: 27.9s	remaining: 20.9s
# 76:	learn: 1853.9846538	total: 28.2s	remaining: 20.5s
# 77:	learn: 1847.6455055	total: 28.6s	remaining: 20.2s
# 78:	learn: 1841.2370008	total: 28.9s	remaining: 19.8s
# 79:	learn: 1835.3071366	total: 29.2s	remaining: 19.4s
# 80:	learn: 1829.5346499	total: 29.6s	remaining: 19s
# 81:	learn: 1824.0749054	total: 30s	remaining: 18.7s
# 82:	learn: 1818.7644861	total: 30.3s	remaining: 18.3s
# 83:	learn: 1813.3212937	total: 30.7s	remaining: 17.9s
# 84:	learn: 1808.4509563	total: 31s	remaining: 17.5s
# 85:	learn: 1803.8154457	total: 31.4s	remaining: 17.2s
# 86:	learn: 1799.4506145	total: 31.8s	remaining: 16.8s
# 87:	learn: 1795.2352915	total: 32.1s	remaining: 16.4s
# 88:	learn: 1791.0392425	total: 32.5s	remaining: 16.1s
# 89:	learn: 1786.8658969	total: 32.8s	remaining: 15.7s
# 90:	learn: 1782.9379969	total: 33.2s	remaining: 15.3s
# 91:	learn: 1778.9831145	total: 33.5s	remaining: 14.9s
# 92:	learn: 1775.5465748	total: 33.9s	remaining: 14.6s
# 93:	learn: 1771.7892638	total: 34.3s	remaining: 14.2s
# 94:	learn: 1768.0051725	total: 34.6s	remaining: 13.8s
# 95:	learn: 1764.6881701	total: 35s	remaining: 13.5s
# 96:	learn: 1761.4587722	total: 35.3s	remaining: 13.1s
# 97:	learn: 1758.1610222	total: 35.7s	remaining: 12.8s
# 98:	learn: 1755.3862146	total: 36.1s	remaining: 12.4s
# 99:	learn: 1752.3743223	total: 36.5s	remaining: 12s
# 100:	learn: 1749.5296617	total: 36.8s	remaining: 11.7s
# 101:	learn: 1747.0098655	total: 37.2s	remaining: 11.3s
# 102:	learn: 1744.4925030	total: 37.5s	remaining: 10.9s
# 103:	learn: 1739.9549046	total: 37.9s	remaining: 10.6s
# 104:	learn: 1735.9088440	total: 38.3s	remaining: 10.2s
# 105:	learn: 1731.7713609	total: 38.7s	remaining: 9.86s
# 106:	learn: 1727.7495319	total: 39s	remaining: 9.48s
# 107:	learn: 1724.2319239	total: 39.4s	remaining: 9.12s
# 108:	learn: 1720.4297053	total: 39.8s	remaining: 8.77s
# 109:	learn: 1717.2167249	total: 40.2s	remaining: 8.41s
# 110:	learn: 1713.8463603	total: 40.6s	remaining: 8.05s
# 111:	learn: 1710.6156160	total: 41s	remaining: 7.69s
# 112:	learn: 1707.1602758	total: 41.3s	remaining: 7.31s
# 113:	learn: 1704.3315529	total: 41.7s	remaining: 6.95s
# 114:	learn: 1701.5765924	total: 42s	remaining: 6.58s
# 115:	learn: 1698.9498828	total: 42.4s	remaining: 6.21s
# 116:	learn: 1696.9489968	total: 42.8s	remaining: 5.85s
# 117:	learn: 1694.7975947	total: 43.2s	remaining: 5.49s
# 118:	learn: 1692.4510141	total: 43.5s	remaining: 5.12s
# 119:	learn: 1690.0903543	total: 43.9s	remaining: 4.76s
# 120:	learn: 1687.9750103	total: 44.3s	remaining: 4.39s
# 121:	learn: 1685.7108336	total: 44.7s	remaining: 4.03s
# 122:	learn: 1683.2606569	total: 45s	remaining: 3.66s
# 123:	learn: 1681.1495332	total: 45.3s	remaining: 3.29s
# 124:	learn: 1678.3581013	total: 45.7s	remaining: 2.92s
# 125:	learn: 1676.2164752	total: 46.1s	remaining: 2.56s
# 126:	learn: 1674.4071592	total: 46.4s	remaining: 2.19s
# 127:	learn: 1672.3478567	total: 46.8s	remaining: 1.83s
# 128:	learn: 1670.4114720	total: 47.2s	remaining: 1.46s
# 129:	learn: 1668.7818128	total: 47.6s	remaining: 1.1s
# 130:	learn: 1667.1715647	total: 47.9s	remaining: 731ms
# 131:	learn: 1665.0289593	total: 48.3s	remaining: 366ms
# 132:	learn: 1663.7008288	total: 48.7s	remaining: 0us
# RMSE составляет 1676.3379872908895 , training_time 51.9495050907135 , prediction_time 0.16649127006530762

# %%
# Посмотрим важность признаков при помощи графика
cb_imp = cb.feature_importances_
imp = pd.DataFrame(cb_imp, index=data_features2.columns, columns=['features_importance']).sort_values(by='features_importance', ascending=False)
imp
# Out:
#                   features_importance
# RegistrationYear            37.001376
# Power                       22.755141
# Brand                       13.815064
# Kilometer                    8.694006
# VehicleType                  8.690740
# NotRepaired                  3.222141
# FuelType                     2.870281
# Model                        2.025611
# Gearbox                      0.925640

# %%
imp.plot(kind='bar')

# %% [markdown]
# Год регистрации на первом месте с большим отрывом, так же важными признаками являются Мощность и Фирма (суммарно эти три признака имеют общий вес 70%), дальше примерно с одинаковыми показателями следуют Километраж и Тип кузова. Остальные признаки имеют намного меньшую важность (особенно тип коробки передач - меньше 1%).
